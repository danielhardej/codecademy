# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, AUC

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# %%
NUM_EPOCHS = 30
BATCH_SIZE = 8
LEARN_RATE = 0.005

CLASS_MODE = "categorical"
COLOR_MODE = "grayscale"
TARGET_SIZE = (256,256)

# %%
TRAIN_DATA_DIRECTORY = "Covid19-dataset/train"
TEST_DATA_DIRECTORY = "Covid19-dataset/test"

# %%
train_image_data_generator = ImageDataGenerator(rescale=1.0/255,
                                            zoom_range=0.2,
                                            rotation_range=15,
                                            width_shift_range=0.05,
                                            height_shift_range=0.05)

training_iterator = train_image_data_generator.flow_from_directory(TRAIN_DATA_DIRECTORY,
                                                                class_mode=CLASS_MODE,
                                                                color_mode=COLOR_MODE,
                                                                target_size=TARGET_SIZE,
                                                                batch_size=BATCH_SIZE)


test_image_data_generator = ImageDataGenerator(rescale=1.0/255)

test_iterator = test_image_data_generator.flow_from_directory(TEST_DATA_DIRECTORY,
                                                        class_mode=CLASS_MODE,
                                                        color_mode=COLOR_MODE,
                                                        target_size=TARGET_SIZE,
                                                        batch_size=BATCH_SIZE)
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.

# %%
import tensorflow as tf
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(256, 256, 1)))
model.add(tf.keras.layers.Conv2D(64, 5, strides=3, activation="relu"))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(3,3)))
model.add(tf.keras.layers.Conv2D(32, 4, strides=2, activation="relu"))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(tf.keras.layers.Conv2D(16, 3, strides=1, activation="relu"))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(tf.keras.layers.Conv2D(8, 2, strides=1, activation="relu"))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(3,activation="softmax"))
# Out:
# 2022-07-07 16:12:34.134311: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(
            optimizer = tf.keras.optimizers.Adam(learning_rate=LEARN_RATE),
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.AUC()]
            )

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 84, 84, 64)        1664
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 32)        32800
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 16)          4624
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 1, 1, 8)           520
#
#  flatten (Flatten)           (None, 8)                 0
#
#  dense (Dense)               (None, 3)                 27
#
# =================================================================
# Total params: 39,635
# Trainable params: 39,635
# Non-trainable params: 0
# _________________________________________________________________

# %%
# start_time = time.perf_counter()

history = model.fit(
       training_iterator,
       steps_per_epoch = (training_iterator.samples)/BATCH_SIZE,
       epochs = NUM_EPOCHS,
       validation_data = test_iterator,
       validation_steps = (test_iterator.samples)/BATCH_SIZE
)

# elapsed_time = time.perf_counter() - start_time
# print("Elapsed Time: " + str(elapsed_time) + " seconds")
# Out:
# Epoch 1/30
# 15/15 [==============================] - 17s 1s/step - loss: 1.1437 - categorical_accuracy: 0.4183 - auc: 0.5574 - val_loss: 1.0886 - val_categorical_accuracy: 0.4545 - val_auc: 0.6688
# Epoch 2/30
# 15/15 [==============================] - 15s 935ms/step - loss: 1.0795 - categorical_accuracy: 0.4382 - auc: 0.5972 - val_loss: 1.0606 - val_categorical_accuracy: 0.4091 - val_auc: 0.6838
# Epoch 3/30
# 15/15 [==============================] - 15s 942ms/step - loss: 1.0725 - categorical_accuracy: 0.4622 - auc: 0.6248 - val_loss: 1.0375 - val_categorical_accuracy: 0.5758 - val_auc: 0.7464
# Epoch 4/30
# 15/15 [==============================] - 13s 823ms/step - loss: 1.0124 - categorical_accuracy: 0.5100 - auc: 0.6799 - val_loss: 1.0090 - val_categorical_accuracy: 0.5303 - val_auc: 0.6836
# Epoch 5/30
# 15/15 [==============================] - 13s 818ms/step - loss: 0.8857 - categorical_accuracy: 0.6056 - auc: 0.7759 - val_loss: 0.8200 - val_categorical_accuracy: 0.6061 - val_auc: 0.8073
# Epoch 6/30
# 15/15 [==============================] - 13s 827ms/step - loss: 0.7181 - categorical_accuracy: 0.7171 - auc: 0.8677 - val_loss: 0.4882 - val_categorical_accuracy: 0.8636 - val_auc: 0.9543
# Epoch 7/30
# 15/15 [==============================] - 13s 838ms/step - loss: 0.5677 - categorical_accuracy: 0.8088 - auc: 0.9168 - val_loss: 0.4873 - val_categorical_accuracy: 0.8030 - val_auc: 0.9379
# Epoch 8/30
# 15/15 [==============================] - 13s 845ms/step - loss: 0.4817 - categorical_accuracy: 0.8127 - auc: 0.9383 - val_loss: 0.3727 - val_categorical_accuracy: 0.9091 - val_auc: 0.9661
# Epoch 9/30
# 15/15 [==============================] - 13s 825ms/step - loss: 0.3799 - categorical_accuracy: 0.8486 - auc: 0.9592 - val_loss: 0.4464 - val_categorical_accuracy: 0.8485 - val_auc: 0.9558
# Epoch 10/30
# 15/15 [==============================] - 13s 846ms/step - loss: 0.3855 - categorical_accuracy: 0.8406 - auc: 0.9592 - val_loss: 0.3657 - val_categorical_accuracy: 0.9242 - val_auc: 0.9660
# Epoch 11/30
# 15/15 [==============================] - 13s 813ms/step - loss: 0.3246 - categorical_accuracy: 0.9004 - auc: 0.9704 - val_loss: 0.3450 - val_categorical_accuracy: 0.9242 - val_auc: 0.9706
# Epoch 12/30
# 15/15 [==============================] - 13s 816ms/step - loss: 0.2719 - categorical_accuracy: 0.9203 - auc: 0.9764 - val_loss: 0.3974 - val_categorical_accuracy: 0.8788 - val_auc: 0.9640
# Epoch 13/30
# 15/15 [==============================] - 13s 807ms/step - loss: 0.3845 - categorical_accuracy: 0.8526 - auc: 0.9579 - val_loss: 0.3639 - val_categorical_accuracy: 0.8939 - val_auc: 0.9652
# Epoch 14/30
# 15/15 [==============================] - 13s 806ms/step - loss: 0.4517 - categorical_accuracy: 0.8167 - auc: 0.9447 - val_loss: 0.3975 - val_categorical_accuracy: 0.8485 - val_auc: 0.9609
# Epoch 15/30
# 15/15 [==============================] - 13s 831ms/step - loss: 0.3237 - categorical_accuracy: 0.8725 - auc: 0.9705 - val_loss: 0.5741 - val_categorical_accuracy: 0.8030 - val_auc: 0.9295
# Epoch 16/30
# 15/15 [==============================] - 13s 821ms/step - loss: 0.3095 - categorical_accuracy: 0.9004 - auc: 0.9749 - val_loss: 0.3799 - val_categorical_accuracy: 0.8939 - val_auc: 0.9665
# Epoch 17/30
# 15/15 [==============================] - 13s 822ms/step - loss: 0.2478 - categorical_accuracy: 0.9084 - auc: 0.9819 - val_loss: 0.5150 - val_categorical_accuracy: 0.8636 - val_auc: 0.9489
# Epoch 18/30
# 15/15 [==============================] - 13s 825ms/step - loss: 0.3404 - categorical_accuracy: 0.8805 - auc: 0.9671 - val_loss: 0.3374 - val_categorical_accuracy: 0.8939 - val_auc: 0.9716
# Epoch 19/30
# 15/15 [==============================] - 13s 811ms/step - loss: 0.2724 - categorical_accuracy: 0.8964 - auc: 0.9782 - val_loss: 0.4193 - val_categorical_accuracy: 0.8788 - val_auc: 0.9591
# Epoch 20/30
# 15/15 [==============================] - 13s 811ms/step - loss: 0.2556 - categorical_accuracy: 0.9044 - auc: 0.9822 - val_loss: 0.3572 - val_categorical_accuracy: 0.8939 - val_auc: 0.9694
# Epoch 21/30
# 15/15 [==============================] - 13s 825ms/step - loss: 0.2660 - categorical_accuracy: 0.9203 - auc: 0.9797 - val_loss: 0.3359 - val_categorical_accuracy: 0.8939 - val_auc: 0.9718
# Epoch 22/30
# 15/15 [==============================] - 13s 808ms/step - loss: 0.3418 - categorical_accuracy: 0.8805 - auc: 0.9645 - val_loss: 0.4308 - val_categorical_accuracy: 0.8636 - val_auc: 0.9611
# Epoch 23/30
# 15/15 [==============================] - 13s 816ms/step - loss: 0.2676 - categorical_accuracy: 0.9044 - auc: 0.9807 - val_loss: 0.3091 - val_categorical_accuracy: 0.9091 - val_auc: 0.9775
# Epoch 24/30
# 15/15 [==============================] - 13s 817ms/step - loss: 0.4070 - categorical_accuracy: 0.8845 - auc: 0.9560 - val_loss: 0.4119 - val_categorical_accuracy: 0.8939 - val_auc: 0.9643
# Epoch 25/30
# 15/15 [==============================] - 13s 849ms/step - loss: 0.3027 - categorical_accuracy: 0.8884 - auc: 0.9749 - val_loss: 0.3259 - val_categorical_accuracy: 0.9242 - val_auc: 0.9737
# Epoch 26/30
# 15/15 [==============================] - 14s 872ms/step - loss: 0.2945 - categorical_accuracy: 0.8805 - auc: 0.9759 - val_loss: 0.3441 - val_categorical_accuracy: 0.8939 - val_auc: 0.9698
# Epoch 27/30
# 15/15 [==============================] - 13s 877ms/step - loss: 0.2207 - categorical_accuracy: 0.9363 - auc: 0.9837 - val_loss: 0.4408 - val_categorical_accuracy: 0.9091 - val_auc: 0.9626
# Epoch 28/30
# 15/15 [==============================] - 13s 825ms/step - loss: 0.2343 - categorical_accuracy: 0.9084 - auc: 0.9852 - val_loss: 0.3610 - val_categorical_accuracy: 0.8788 - val_auc: 0.9717
# Epoch 29/30
# 15/15 [==============================] - 13s 841ms/step - loss: 0.2247 - categorical_accuracy: 0.9323 - auc: 0.9852 - val_loss: 0.3216 - val_categorical_accuracy: 0.8939 - val_auc: 0.9761
# Epoch 30/30
# 15/15 [==============================] - 13s 830ms/step - loss: 0.2286 - categorical_accuracy: 0.9203 - auc: 0.9843 - val_loss: 0.3221 - val_categorical_accuracy: 0.8788 - val_auc: 0.9738

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Categorical Cross-Entropy')
plt.ylabel('Categorical Cross-Entropy')
plt.xlabel('Epoch')
plt.legend(['Training Data', 'Validation Data'], loc='upper right')
plt.show()

plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Data', 'Validation Data'], loc='lower right')
plt.show()

plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('Area Under FOC Curve')
plt.xlabel('Epoch')
plt.legend(['Training Data', 'Validation Data'], loc='lower right')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

model_predictions = model.predict(test_iterator, steps=(test_iterator.samples)/BATCH_SIZE)

predicted_classes = np.argmax(model_predictions, axis=1)
true_classes = test_iterator.classes
class_labels = list(test_iterator.class_indices.keys())

print("Classification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))   

print("Confusion Matrix:")
cm = confusion_matrix(true_classes,predicted_classes)
fig, ax = plt.subplots(figsize=(12, 10))
heatmap = sns.heatmap(cm, fmt='g', cmap='Greens', annot=True, ax=ax)
ax.set_xlabel('Predicted class')
ax.set_ylabel('True class')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_labels)
ax.yaxis.set_ticklabels(class_labels)
# Out:
# 4/4 [==============================] - 2s 367ms/step
# Classification Report:
#                  precision    recall  f1-score   support
#
#           Covid       0.42      0.38      0.40        26
#          Normal       0.35      0.35      0.35        20
# Viral Pneumonia       0.23      0.25      0.24        20
#
#        accuracy                           0.33        66
#       macro avg       0.33      0.33      0.33        66
#    weighted avg       0.34      0.33      0.34        66
#
# Confusion Matrix:
# [Text(0, 0.5, 'Covid'),
#  Text(0, 1.5, 'Normal'),
#  Text(0, 2.5, 'Viral Pneumonia')]
