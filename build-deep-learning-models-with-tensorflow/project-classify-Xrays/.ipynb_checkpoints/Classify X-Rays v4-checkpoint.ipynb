# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, AUC

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# %%
NUM_EPOCHS = 40
BATCH_SIZE = 8
LEARN_RATE = 0.005

CLASS_MODE = "categorical"
COLOR_MODE = "grayscale"
TARGET_SIZE = (256,256)

# %%
TRAIN_DATA_DIRECTORY = "Covid19-dataset/train"
TEST_DATA_DIRECTORY = "Covid19-dataset/test"

# %%
train_image_data_generator = ImageDataGenerator(rescale=1.0/255,
                                            zoom_range=0.2,
                                            rotation_range=15,
                                            width_shift_range=0.05,
                                            height_shift_range=0.05)

training_iterator = train_image_data_generator.flow_from_directory(TRAIN_DATA_DIRECTORY,
                                                                class_mode=CLASS_MODE,
                                                                color_mode=COLOR_MODE,
                                                                target_size=TARGET_SIZE,
                                                                batch_size=BATCH_SIZE)


test_image_data_generator = ImageDataGenerator(rescale=1.0/255)

test_iterator = test_image_data_generator.flow_from_directory(TEST_DATA_DIRECTORY,
                                                        class_mode=CLASS_MODE,
                                                        color_mode=COLOR_MODE,
                                                        target_size=TARGET_SIZE,
                                                        batch_size=BATCH_SIZE)
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.

# %%
import tensorflow as tf

model = tf.keras.Sequential()

model.add(tf.keras.Input(shape=(256, 256, 1)))

model.add(tf.keras.layers.Conv2D(64, 5, strides=3, activation="relu"))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=(3,3)))

model.add(tf.keras.layers.Conv2D(32, 4, strides=2, activation="relu"))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(tf.keras.layers.Conv2D(16, 3, strides=1, activation="relu"))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(tf.keras.layers.Conv2D(8, 2, strides=1, activation="relu"))
#model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(tf.keras.layers.Dense(8,activation="relu"))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(3,activation="softmax"))

# %%
model.compile(
            optimizer = tf.keras.optimizers.Adam(learning_rate=LEARN_RATE),
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.AUC()]
            )

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 84, 84, 64)        1664
#
#  max_pooling2d_14 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 13, 13, 32)        32800
#
#  max_pooling2d_15 (MaxPoolin  (None, 6, 6, 32)         0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 4, 4, 16)          4624
#
#  max_pooling2d_16 (MaxPoolin  (None, 2, 2, 16)         0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 1, 1, 8)           520
#
#  dense_2 (Dense)             (None, 1, 1, 8)           72
#
#  flatten_2 (Flatten)         (None, 8)                 0
#
#  dense_3 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 39,707
# Trainable params: 39,707
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time

start_time = time.perf_counter()

history = model.fit(
       training_iterator,
       steps_per_epoch = (training_iterator.samples)/BATCH_SIZE,
       epochs = NUM_EPOCHS,
       validation_data = test_iterator,
       validation_steps = (test_iterator.samples)/BATCH_SIZE
)

elapsed_time = time.perf_counter() - start_time
print()

print("Elapsed Time: " + str(elapsed_time) + " seconds")
print(str(elapsed_time/60) + " minutes")
# Out:
# Epoch 1/40
# 31/31 [==============================] - 16s 492ms/step - loss: 1.1316 - categorical_accuracy: 0.3865 - auc_2: 0.5170 - val_loss: 1.0918 - val_categorical_accuracy: 0.3939 - val_auc_2: 0.5379
# Epoch 2/40
# 31/31 [==============================] - 17s 557ms/step - loss: 1.0813 - categorical_accuracy: 0.4422 - auc_2: 0.5631 - val_loss: 1.0919 - val_categorical_accuracy: 0.3939 - val_auc_2: 0.5406
# Epoch 3/40
# 31/31 [==============================] - 16s 516ms/step - loss: 1.0800 - categorical_accuracy: 0.4422 - auc_2: 0.5664 - val_loss: 1.0904 - val_categorical_accuracy: 0.3939 - val_auc_2: 0.5478
# Epoch 4/40
# 31/31 [==============================] - 15s 496ms/step - loss: 1.0765 - categorical_accuracy: 0.4422 - auc_2: 0.5750 - val_loss: 1.0895 - val_categorical_accuracy: 0.3939 - val_auc_2: 0.5845
# Epoch 5/40
# 31/31 [==============================] - 14s 452ms/step - loss: 1.0398 - categorical_accuracy: 0.4821 - auc_2: 0.6652 - val_loss: 0.8597 - val_categorical_accuracy: 0.6667 - val_auc_2: 0.8758
# Epoch 6/40
# 31/31 [==============================] - 15s 480ms/step - loss: 0.7509 - categorical_accuracy: 0.6853 - auc_2: 0.8549 - val_loss: 0.7174 - val_categorical_accuracy: 0.6667 - val_auc_2: 0.8449
# Epoch 7/40
# 31/31 [==============================] - 15s 482ms/step - loss: 0.6937 - categorical_accuracy: 0.7052 - auc_2: 0.8706 - val_loss: 0.7985 - val_categorical_accuracy: 0.6061 - val_auc_2: 0.8129
# Epoch 8/40
# 31/31 [==============================] - 15s 464ms/step - loss: 0.6881 - categorical_accuracy: 0.7171 - auc_2: 0.8711 - val_loss: 1.1441 - val_categorical_accuracy: 0.5909 - val_auc_2: 0.7320
# Epoch 9/40
# 31/31 [==============================] - 14s 451ms/step - loss: 0.7644 - categorical_accuracy: 0.6375 - auc_2: 0.8377 - val_loss: 0.7616 - val_categorical_accuracy: 0.5758 - val_auc_2: 0.8093
# Epoch 10/40
# 31/31 [==============================] - 14s 443ms/step - loss: 0.6369 - categorical_accuracy: 0.7052 - auc_2: 0.8879 - val_loss: 0.5809 - val_categorical_accuracy: 0.6061 - val_auc_2: 0.8854
# Epoch 11/40
# 31/31 [==============================] - 15s 485ms/step - loss: 0.6158 - categorical_accuracy: 0.7171 - auc_2: 0.8955 - val_loss: 0.6539 - val_categorical_accuracy: 0.6364 - val_auc_2: 0.8820
# Epoch 12/40
# 31/31 [==============================] - 15s 490ms/step - loss: 0.5957 - categorical_accuracy: 0.7450 - auc_2: 0.9004 - val_loss: 0.6789 - val_categorical_accuracy: 0.6667 - val_auc_2: 0.8716
# Epoch 13/40
# 31/31 [==============================] - 14s 461ms/step - loss: 0.4894 - categorical_accuracy: 0.8048 - auc_2: 0.9358 - val_loss: 0.5160 - val_categorical_accuracy: 0.7576 - val_auc_2: 0.9295
# Epoch 14/40
# 31/31 [==============================] - 14s 461ms/step - loss: 0.5456 - categorical_accuracy: 0.7610 - auc_2: 0.9193 - val_loss: 0.6475 - val_categorical_accuracy: 0.6667 - val_auc_2: 0.8839
# Epoch 15/40
# 31/31 [==============================] - 14s 433ms/step - loss: 0.4927 - categorical_accuracy: 0.8127 - auc_2: 0.9337 - val_loss: 0.6087 - val_categorical_accuracy: 0.8030 - val_auc_2: 0.9029
# Epoch 16/40
# 31/31 [==============================] - 14s 438ms/step - loss: 0.4416 - categorical_accuracy: 0.8327 - auc_2: 0.9489 - val_loss: 0.3716 - val_categorical_accuracy: 0.8485 - val_auc_2: 0.9685
# Epoch 17/40
# 31/31 [==============================] - 15s 474ms/step - loss: 0.4320 - categorical_accuracy: 0.8327 - auc_2: 0.9459 - val_loss: 0.6084 - val_categorical_accuracy: 0.6818 - val_auc_2: 0.9192
# Epoch 18/40
# 31/31 [==============================] - 13s 426ms/step - loss: 0.5021 - categorical_accuracy: 0.7928 - auc_2: 0.9294 - val_loss: 0.4016 - val_categorical_accuracy: 0.8636 - val_auc_2: 0.9651
# Epoch 19/40
# 31/31 [==============================] - 13s 412ms/step - loss: 0.3588 - categorical_accuracy: 0.8884 - auc_2: 0.9632 - val_loss: 0.5298 - val_categorical_accuracy: 0.8636 - val_auc_2: 0.9337
# Epoch 20/40
# 31/31 [==============================] - 15s 489ms/step - loss: 0.3779 - categorical_accuracy: 0.8725 - auc_2: 0.9580 - val_loss: 0.6141 - val_categorical_accuracy: 0.7424 - val_auc_2: 0.9133
# Epoch 21/40
# 31/31 [==============================] - 14s 453ms/step - loss: 0.3353 - categorical_accuracy: 0.8845 - auc_2: 0.9676 - val_loss: 0.3897 - val_categorical_accuracy: 0.8485 - val_auc_2: 0.9595
# Epoch 22/40
# 31/31 [==============================] - 14s 438ms/step - loss: 0.3011 - categorical_accuracy: 0.8964 - auc_2: 0.9732 - val_loss: 0.3470 - val_categorical_accuracy: 0.8788 - val_auc_2: 0.9661
# Epoch 23/40
# 31/31 [==============================] - 13s 419ms/step - loss: 0.3384 - categorical_accuracy: 0.8606 - auc_2: 0.9684 - val_loss: 0.2924 - val_categorical_accuracy: 0.8939 - val_auc_2: 0.9766
# Epoch 24/40
# 31/31 [==============================] - 15s 464ms/step - loss: 0.4781 - categorical_accuracy: 0.8287 - auc_2: 0.9359 - val_loss: 0.5214 - val_categorical_accuracy: 0.8030 - val_auc_2: 0.9287
# Epoch 25/40
# 31/31 [==============================] - 15s 473ms/step - loss: 0.3867 - categorical_accuracy: 0.8526 - auc_2: 0.9587 - val_loss: 0.5476 - val_categorical_accuracy: 0.8333 - val_auc_2: 0.9353
# Epoch 26/40
# 31/31 [==============================] - 16s 503ms/step - loss: 0.3492 - categorical_accuracy: 0.8526 - auc_2: 0.9664 - val_loss: 0.4435 - val_categorical_accuracy: 0.8333 - val_auc_2: 0.9479
# Epoch 27/40
# 31/31 [==============================] - 17s 544ms/step - loss: 0.3691 - categorical_accuracy: 0.8645 - auc_2: 0.9611 - val_loss: 0.7040 - val_categorical_accuracy: 0.8333 - val_auc_2: 0.9094
# Epoch 28/40
# 31/31 [==============================] - 15s 471ms/step - loss: 0.3498 - categorical_accuracy: 0.8606 - auc_2: 0.9647 - val_loss: 0.4762 - val_categorical_accuracy: 0.8030 - val_auc_2: 0.9428
# Epoch 29/40
# 31/31 [==============================] - 15s 475ms/step - loss: 0.2746 - categorical_accuracy: 0.8964 - auc_2: 0.9802 - val_loss: 0.4203 - val_categorical_accuracy: 0.8182 - val_auc_2: 0.9523
# Epoch 30/40
# 31/31 [==============================] - 15s 474ms/step - loss: 0.3810 - categorical_accuracy: 0.8406 - auc_2: 0.9611 - val_loss: 0.4313 - val_categorical_accuracy: 0.8333 - val_auc_2: 0.9537
# Epoch 31/40
# 31/31 [==============================] - 15s 468ms/step - loss: 0.3656 - categorical_accuracy: 0.8606 - auc_2: 0.9620 - val_loss: 0.4760 - val_categorical_accuracy: 0.8485 - val_auc_2: 0.9439
# Epoch 32/40
# 31/31 [==============================] - 15s 469ms/step - loss: 0.2788 - categorical_accuracy: 0.9124 - auc_2: 0.9755 - val_loss: 0.4788 - val_categorical_accuracy: 0.8182 - val_auc_2: 0.9395
# Epoch 33/40
# 31/31 [==============================] - 14s 439ms/step - loss: 0.2721 - categorical_accuracy: 0.9004 - auc_2: 0.9759 - val_loss: 0.3246 - val_categorical_accuracy: 0.8939 - val_auc_2: 0.9683
# Epoch 34/40
# 31/31 [==============================] - 14s 444ms/step - loss: 0.3793 - categorical_accuracy: 0.8685 - auc_2: 0.9614 - val_loss: 0.5416 - val_categorical_accuracy: 0.7727 - val_auc_2: 0.9326
# Epoch 35/40
# 31/31 [==============================] - 15s 468ms/step - loss: 0.3904 - categorical_accuracy: 0.8606 - auc_2: 0.9579 - val_loss: 0.3172 - val_categorical_accuracy: 0.8485 - val_auc_2: 0.9733
# Epoch 36/40
# 31/31 [==============================] - 14s 450ms/step - loss: 0.3536 - categorical_accuracy: 0.8884 - auc_2: 0.9620 - val_loss: 0.4120 - val_categorical_accuracy: 0.8485 - val_auc_2: 0.9539
# Epoch 37/40
# 31/31 [==============================] - 15s 477ms/step - loss: 0.2393 - categorical_accuracy: 0.9124 - auc_2: 0.9867 - val_loss: 0.3818 - val_categorical_accuracy: 0.8636 - val_auc_2: 0.9647
# Epoch 38/40
# 31/31 [==============================] - 16s 497ms/step - loss: 0.2441 - categorical_accuracy: 0.9283 - auc_2: 0.9808 - val_loss: 0.3565 - val_categorical_accuracy: 0.8485 - val_auc_2: 0.9630
# Epoch 39/40
# 31/31 [==============================] - 15s 470ms/step - loss: 0.2345 - categorical_accuracy: 0.9283 - auc_2: 0.9834 - val_loss: 0.3866 - val_categorical_accuracy: 0.8939 - val_auc_2: 0.9641
# Epoch 40/40
# 31/31 [==============================] - 15s 491ms/step - loss: 0.3218 - categorical_accuracy: 0.8924 - auc_2: 0.9701 - val_loss: 0.4202 - val_categorical_accuracy: 0.9091 - val_auc_2: 0.9652
#
# Elapsed Time: 589.9255578340001 seconds
# 9.832092630566668 minutes

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.metrics import CategoricalAccuracy, AUC

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Categorical Cross-Entropy')
plt.ylabel('Categorical Cross-Entropy')
plt.xlabel('Epoch')
plt.legend(['Training Data', 'Validation Data'], loc='upper right')
plt.show()

plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Data', 'Validation Data'], loc='lower right')
plt.show()

plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('Area Under FOC Curve')
plt.xlabel('Epoch')
plt.legend(['Training Data', 'Validation Data'], loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [34], in <cell line: 20>()
#      17 plt.legend(['Training Data', 'Validation Data'], loc='lower right')
#      18 plt.show()
# ---> 20 plt.plot(history.history['auc'])
#      21 plt.plot(history.history['val_auc'])
#      22 plt.title('Model AUC')
#
# KeyError: 'auc'

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

model_predictions = model.predict(test_iterator, steps=(test_iterator.samples)/BATCH_SIZE)

predicted_classes = np.argmax(model_predictions, axis=1)
true_classes = test_iterator.classes
class_labels = list(test_iterator.class_indices.keys())

print("Classification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))   

print("Confusion Matrix:")
cm = confusion_matrix(true_classes,predicted_classes)
fig, ax = plt.subplots(figsize=(12, 10))
heatmap = sns.heatmap(cm, fmt='g', cmap='Greens', annot=True, ax=ax)
ax.set_xlabel('Predicted class')
ax.set_ylabel('True class')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_labels)
ax.yaxis.set_ticklabels(class_labels)
# Out:
# 8/8 [==============================] - 2s 194ms/step
# Classification Report:
#                  precision    recall  f1-score   support
#
#           Covid       0.48      0.42      0.45        26
#          Normal       0.26      0.25      0.26        20
# Viral Pneumonia       0.21      0.25      0.23        20
#
#        accuracy                           0.32        66
#       macro avg       0.32      0.31      0.31        66
#    weighted avg       0.33      0.32      0.32        66
#
# Confusion Matrix:
# [Text(0, 0.5, 'Covid'),
#  Text(0, 1.5, 'Normal'),
#  Text(0, 2.5, 'Viral Pneumonia')]
